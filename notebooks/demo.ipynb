# %%
# Add relevant Jupyter notebook extensions

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['/Users/ericaaa/Desktop/b1-coding-practical-mt24/notebooks', '/Users/ericaaa/opt/anaconda3/lib/python39.zip', '/Users/ericaaa/opt/anaconda3/lib/python3.9', '/Users/ericaaa/opt/anaconda3/lib/python3.9/lib-dynload', '', '/Users/ericaaa/opt/anaconda3/lib/python3.9/site-packages', '/Users/ericaaa/opt/anaconda3/lib/python3.9/site-packages/aeosa']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules
import sys 
import os
# include workspace in path for uuv_mission imports 
workspace_dir = os.path.abspath('..')
sys.path.append(workspace_dir)
# Import relevant modules
from uuv_mission.dynamic import ClosedLoop
from uuv_mission.control import PDController 
from uuv_mission.dynamic import Mission 
from uuv_mission.dynamic import Submarine

sub = Submarine()
controller = PDController(K_P=0.15, K_D=0.6)
# Instantiate your controller (depending on your implementation)
closed_loop = ClosedLoop(sub, controller)
mission = Mission.from_csv('/Users/ericaaa/Desktop/b1-coding-practical-mt24/data/mission.csv') # You must implement this method in the Mission class

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
